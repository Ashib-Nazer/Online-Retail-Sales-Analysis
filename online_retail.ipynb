# %%
import pandas as pd

# %%
data = pd.read_excel('online_retail_II.xlsx')
data
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
data.dtypes
# Out:
# Invoice                object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# Price                 float64
# Customer ID           float64
# Country                object
# dtype: object

# %%
data.isnull().sum() / len(data) * 100
# Out:
# Invoice         0.000000
# StockCode       0.000000
# Description     0.557225
# Quantity        0.000000
# InvoiceDate     0.000000
# Price           0.000000
# Customer ID    20.539488
# Country         0.000000
# dtype: float64

# %%
data['Description'] = data['Description'].fillna(data['Description'].mode())

# %%
data['Description'] = data['Description'].fillna(data['Description'].ffill())

# %%
data['Customer ID'].max()
# Out:
# 18287.0

# %%
data['Customer ID'].min()
# Out:
# 12346.0

# %%
data['Customer ID'] = data['Customer ID'].fillna(data['Customer ID'].median())

# %%
data.duplicated().sum()
# Out:
# 6865

# %%
data.drop_duplicates(inplace=True)

# %%
data['Country'].value_counts()
# Out:
# Country
# United Kingdom          479047
# EIRE                      9660
# Germany                   8120
# France                    5754
# Netherlands               2768
# Spain                     1271
# Switzerland               1187
# Portugal                  1098
# Belgium                   1053
# Channel Islands            906
# Sweden                     901
# Italy                      729
# Australia                  654
# Cyprus                     546
# Austria                    537
# Greece                     517
# United Arab Emirates       432
# Denmark                    428
# Norway                     369
# Finland                    354
# Unspecified                310
# USA                        244
# Japan                      224
# Poland                     194
# Malta                      172
# Lithuania                  154
# Singapore                  117
# RSA                        111
# Bahrain                    107
# Canada                      77
# ...

# %%
data['Revenue'] = data['Quantity'] * data['Price']

# %%
data['Country'].value_counts()
# Out:
# Country
# United Kingdom          479047
# EIRE                      9660
# Germany                   8120
# France                    5754
# Netherlands               2768
# Spain                     1271
# Switzerland               1187
# Portugal                  1098
# Belgium                   1053
# Channel Islands            906
# Sweden                     901
# Italy                      729
# Australia                  654
# Cyprus                     546
# Austria                    537
# Greece                     517
# United Arab Emirates       432
# Denmark                    428
# Norway                     369
# Finland                    354
# Unspecified                310
# USA                        244
# Japan                      224
# Poland                     194
# Malta                      172
# Lithuania                  154
# Singapore                  117
# RSA                        111
# Bahrain                    107
# Canada                      77
# ...

# %%
data.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
uk = data[data['Country']=='United Kingdom']

# %%
uk['Price'].sum()
# Out:
# 2189586.5730000003

# %%
uk['Quantity'].sum()
# Out:
# 4410572

# %%
data['Revenue'] = data['Quantity'] * data['Price']

# %%
data.groupby('Country')[['Revenue','Quantity']].sum().sort_values(by='Quantity',ascending=False)
# Out:
#                           Revenue  Quantity
# Country
# United Kingdom        8161692.763   4410572
# Denmark                 46972.950    227030
# EIRE                   352235.680    188659
# Netherlands            263861.760    181822
# Germany                195920.421    107026
# France                 130661.550     74317
# Sweden                  51190.110     52226
# Switzerland             43343.410     22053
# Australia               30051.800     20053
# Spain                   37052.130     18317
# Belgium                 22644.030     11974
# Portugal                23765.230     11875
# Channel Islands         21367.320     10994
# Norway                   4079.570      7863
# Italy                   13774.390      7285
# Japan                    8435.960      6604
# Austria                 13023.280      6479
# Greece                  14284.970      6151
# United Arab Emirates     8046.370      5746
# Cyprus                  11173.800      4356
# ...

# %%
data.groupby('Country')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Country
# United Kingdom          8161692.763
# EIRE                     352235.680
# Netherlands              263861.760
# Germany                  195920.421
# France                   130661.550
# Sweden                    51190.110
# Denmark                   46972.950
# Switzerland               43343.410
# Spain                     37052.130
# Australia                 30051.800
# Portugal                  23765.230
# Belgium                   22644.030
# Channel Islands           21367.320
# Greece                    14284.970
# Italy                     13774.390
# Austria                   13023.280
# Cyprus                    11173.800
# Japan                      8435.960
# United Arab Emirates       8046.370
# Finland                    7187.710
# Unspecified                4937.530
# Lithuania                  4892.680
# USA                        4555.620
# Norway                     4079.570
# Singapore                  4037.770
# Hong Kong                  3922.260
# ...

# %%
data['Revenue'] = data['Quantity'] * data['Price']

# %%
data.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country  Revenue
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom     83.4
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom     81.0
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom     81.0
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom    100.8
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom     30.0

# %%
uk_revenue = 2189586.573
uk_revenue / data['Revenue'].sum() * 100
# Out:
# 23.034275933174143

# %%
data['Description'].value_counts().to_dict()
# Out:
# {'WHITE HANGING HEART T-LIGHT HOLDER': 3530,
#  'REGENCY CAKESTAND 3 TIER': 2220,
#  'STRAWBERRY CERAMIC TRINKET BOX': 1814,
#  'ASSORTED COLOUR BIRD ORNAMENT': 1463,
#  'PACK OF 72 RETRO SPOT CAKE CASES': 1449,
#  '60 TEATIME FAIRY CAKE CASES': 1402,
#  'HOME BUILDING BLOCK WORD': 1361,
#  'JUMBO BAG RED RETROSPOT': 1305,
#  'LUNCH BAG RED SPOTTY': 1279,
#  'JUMBO STORAGE BAG SUKI': 1222,
#  'BAKING SET 9 PIECE RETROSPOT ': 1212,
#  'REX CASH+CARRY JUMBO SHOPPER': 1184,
#  'PACK OF 60 PINK PAISLEY CAKE CASES': 1183,
#  'WOODEN FRAME ANTIQUE WHITE ': 1182,
#  'LUNCH BAG  BLACK SKULL.': 1166,
#  'LUNCH BAG SUKI  DESIGN ': 1142,
#  'HEART OF WICKER LARGE': 1134,
#  'LOVE BUILDING BLOCK WORD': 1121,
#  'RED HANGING HEART T-LIGHT HOLDER': 1112,
#  'JUMBO BAG STRAWBERRY': 1095,
#  'JUMBO SHOPPER VINTAGE RED PAISLEY': 1082,
#  'SWEETHEART CERAMIC TRINKET BOX': 1078,
#  'HEART OF WICKER SMALL': 1067,
#  'HOT WATER BOTTLE TEA AND SYMPATHY': 1041,
#  'PARTY BUNTING': 1039,
# ...

# %%
# data.to_excel('cleaned_online_retail.xlsx',index=False)

# %%
data['InvoiceDate'].min()
# Out:
# Timestamp('2009-12-01 07:45:00')

# %%
data['InvoiceDate'].max()
# Out:
# Timestamp('2010-12-09 20:01:00')
